# %%
def cost(b):
    return (b - 4) ** 2

# %%
def slope(b):
    return 2 * (b - 4)

# %%
b = -8

# %%
for i in range(100):
    b = b - .1 * slope(b)
    print(b)
# Out:
# -5.6
# -3.6799999999999997
# -2.1439999999999997
# -0.9151999999999996
# 0.06784000000000034
# 0.8542720000000004
# 1.4834176000000003
# 1.9867340800000002
# 2.3893872640000002
# 2.7115098112
# 2.96920784896
# 3.175366279168
# 3.3402930233344
# 3.47223441866752
# 3.577787534934016
# 3.6622300279472126
# 3.7297840223577703
# 3.7838272178862162
# 3.827061774308973
# 3.861649419447178
# 3.8893195355577426
# 3.911455628446194
# 3.9291645027569553
# 3.9433316022055642
# 3.954665281764451
# 3.963732225411561
# 3.9709857803292485
# 3.9767886242633987
# 3.981430899410719
# 3.985144719528575
# 3.98811577562286
# 3.990492620498288
# 3.9923940963986304
# 3.993915277118904
# 3.9951322216951235
# 3.9961057773560986
# 3.996884621884879
# 3.997507697507903
# 3.9980061580063224
# 3.998404926405058
# 3.9987239411240463
# 3.998979152899237
# 3.9991833223193898
# 3.999346657855512
# 3.9994773262844094
# 3.9995818610275276
# 3.999665488822022
# 3.9997323910576177
# 3.999785912846094
# ...
